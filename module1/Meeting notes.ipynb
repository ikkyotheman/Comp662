# %% [markdown]
# We will be using SQLlite for class. Installed DB Browser. Her project files were saving as .db file. Having an issue figuring this out.

# %% [markdown]
# From now on, whenever using a database, turn logging on
